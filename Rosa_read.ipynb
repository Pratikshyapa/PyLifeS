# %%
#importing pandas as "pd"
import pandas as pd
import numpy as np

# %%
#calling a dataframe in pandas to read the csv
dataFrame = pd.read_csv(r"C:\Users\HP\Desktop\Archisman_Python\Rosa.csv")

# %%
#printing the output in a dataframe
print(dataFrame)
# Out:
#     genus  hyb         species
# 0    Rosa  NaN        abietina
# 1    Rosa  NaN          abrica
# 2    Rosa  NaN    abutalybovii
# 3    Rosa  NaN      abyssinica
# 4    Rosa  NaN     achburensis
# ..    ...  ...             ...
# 322  Rosa  NaN        xanthina
# 323  Rosa  NaN          zalana
# 324  Rosa  NaN    zaramagensis
# 325  Rosa  NaN  zhongdianensis
# 326  Rosa  NaN       zuvandica
#
# [327 rows x 3 columns]

# %%
# defining two new dataframe to segregate the hybrid and the pure 
dataFrame_hybrid=dataFrame[dataFrame['hyb'] == 'x']
dataFrame_pure=dataFrame[dataFrame['hyb'].isna()]
A=np.loadtxt('Rosa.csv', delimiter=",", dtype=str)
print(A)
# Out:
# [['genus' 'hyb' 'species']
#  ['Rosa' '' 'abietina']
#  ['Rosa' '' 'abrica']
#  ['Rosa' '' 'abutalybovii']
#  ['Rosa' '' 'abyssinica']
#  ['Rosa' '' 'achburensis']
#  ['Rosa' '' 'acicularis']
#  ['Rosa' '' 'adenophylla']
#  ['Rosa' '' 'agrestis']
#  ['Rosa' '' 'alabukensis']
#  ['Rosa' '' 'alberti']
#  ['Rosa' '' 'alexeenkoi']
#  ['Rosa' 'x' 'alpestris']
#  ['Rosa' '' 'altidaghestanica']
#  ['Rosa' '' 'amblyophylla']
#  ['Rosa' 'x' 'andegavensis']
#  ['Rosa' '' 'arabica']
#  ['Rosa' '' 'arensii']
#  ['Rosa' '' 'arkansana']
#  ['Rosa' '' 'arvensis']
#  ['Rosa' 'x' 'atlantica']
#  ['Rosa' 'x' 'avrayensis']
#  ['Rosa' '' 'awarica']
#  ['Rosa' '' 'baiyushanensis']
#  ['Rosa' '' 'balcarica']
#  ['Rosa' '' 'balsamica']
#  ['Rosa' '' 'banksiae']
#  ['Rosa' '' 'banksiopsis']
#  ['Rosa' 'x' 'baxanensis']
#  ['Rosa' '' 'beauvaisii']
#  ['Rosa' '' 'beggeriana']
#  ['Rosa' '' 'bella']
#  ['Rosa' '' 'bellicosa']
#  ['Rosa' 'x' 'belnensis']
#  ['Rosa' 'x' 'bengyana']
# ...

# %%
#output of hybrid datframe
print(dataFrame_hybrid)
# Out:
#     genus hyb           species
# 11   Rosa   x         alpestris
# 14   Rosa   x      andegavensis
# 19   Rosa   x         atlantica
# 20   Rosa   x        avrayensis
# 27   Rosa   x        baxanensis
# ..    ...  ..               ...
# 311  Rosa   x  verticillacantha
# 312  Rosa   x        victoriana
# 315  Rosa   x     vituperabilis
# 316  Rosa   x         waitziana
# 317  Rosa   x       warleyensis
#
# [80 rows x 3 columns]

# %%
#output of the dataframe  excluding the hybrids
print(dataFrame_pure)
# Out:
#     genus  hyb         species
# 0    Rosa  NaN        abietina
# 1    Rosa  NaN          abrica
# 2    Rosa  NaN    abutalybovii
# 3    Rosa  NaN      abyssinica
# 4    Rosa  NaN     achburensis
# ..    ...  ...             ...
# 322  Rosa  NaN        xanthina
# 323  Rosa  NaN          zalana
# 324  Rosa  NaN    zaramagensis
# 325  Rosa  NaN  zhongdianensis
# 326  Rosa  NaN       zuvandica
#
# [247 rows x 3 columns]

# %%
# saving the dataframe
dataFrame_hybrid.to_csv('rosa_hyb.csv')

# %%
# saving the dataframe
dataFrame_pure.to_csv('rosa_pure.csv')
